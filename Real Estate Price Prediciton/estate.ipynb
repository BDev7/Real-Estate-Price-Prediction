# %%
import pandas
import matplotlib.pyplot as plt

# %%
data=pandas.read_csv("./Delhi_v2.csv")

# %%
data.head()
# Out:
#    Unnamed: 0       price                                            Address  \
# 0           0   5600000.0                  Noida Extension, Noida, Delhi NCR
# 1           1   8800000.0                      Sector 79, Gurgaon, Delhi NCR
# 2           2  16500000.0                     Vaishali, Ghaziabad, Delhi NCR
# 3           3   3810000.0  Link Road, F Block, Sector 50, Noida, Uttar Pr...
# 4           4   6200000.0  Jaypee Pavilion Court Sector 128, Noida, Secto...
#
#      area   latitude  longitude  Bedrooms  Bathrooms  Balcony  \
# 0  1350.0  28.608850  77.460560       3.0        3.0      NaN
# 1  1490.0  28.374236  76.952416       3.0        3.0      NaN
# 2  2385.0  28.645769  77.385110       4.0        5.0      NaN
# 3  1050.0  28.566914  77.436434       2.0        2.0      3.0
# 4  1350.0  28.520732  77.356491       2.0        2.0      3.0
#
#                Status      neworold  parking Furnished_status  Lift  \
# ...

# %%
data.drop(["Address","desc","Landmarks"],axis=1,inplace=True)

# %%
data.head()
# Out:
#    Unnamed: 0       price    area   latitude  longitude  Bedrooms  Bathrooms  \
# 0           0   5600000.0  1350.0  28.608850  77.460560       3.0        3.0
# 1           1   8800000.0  1490.0  28.374236  76.952416       3.0        3.0
# 2           2  16500000.0  2385.0  28.645769  77.385110       4.0        5.0
# 3           3   3810000.0  1050.0  28.566914  77.436434       2.0        2.0
# 4           4   6200000.0  1350.0  28.520732  77.356491       2.0        2.0
#
#    Balcony              Status      neworold  parking Furnished_status  Lift  \
# 0      NaN  Under Construction  New Property      NaN              NaN   2.0
# 1      NaN       Ready to Move  New Property      NaN   Semi-Furnished   2.0
# 2      NaN       Ready to Move  New Property      1.0      Unfurnished   NaN
# 3      3.0                 NaN  New Property      1.0      Unfurnished   2.0
# 4      3.0       Ready to Move        Resale      1.0              NaN   3.0
#
#   type_of_building   Price_sqft
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7738 entries, 0 to 7737
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7738 non-null   int64
#  1   price             7738 non-null   float64
#  2   area              7738 non-null   float64
#  3   latitude          7738 non-null   float64
#  4   longitude         7738 non-null   float64
#  5   Bedrooms          7738 non-null   float64
#  6   Bathrooms         7738 non-null   float64
#  7   Balcony           5166 non-null   float64
#  8   Status            7164 non-null   object
#  9   neworold          7738 non-null   object
#  10  parking           2612 non-null   float64
#  11  Furnished_status  4124 non-null   object
#  12  Lift              1733 non-null   float64
#  13  type_of_building  7738 non-null   object
#  14  Price_sqft        7738 non-null   float64
# dtypes: float64(10), int64(1), object(4)
# ...

# %%
data.fillna(0,inplace=True)

# %%
data.head()
# Out:
#    Unnamed: 0       price    area   latitude  longitude  Bedrooms  Bathrooms  \
# 0           0   5600000.0  1350.0  28.608850  77.460560       3.0        3.0
# 1           1   8800000.0  1490.0  28.374236  76.952416       3.0        3.0
# 2           2  16500000.0  2385.0  28.645769  77.385110       4.0        5.0
# 3           3   3810000.0  1050.0  28.566914  77.436434       2.0        2.0
# 4           4   6200000.0  1350.0  28.520732  77.356491       2.0        2.0
#
#    Balcony              Status      neworold  parking Furnished_status  Lift  \
# 0      0.0  Under Construction  New Property      0.0                0   2.0
# 1      0.0       Ready to Move  New Property      0.0   Semi-Furnished   2.0
# 2      0.0       Ready to Move  New Property      1.0      Unfurnished   0.0
# 3      3.0                   0  New Property      1.0      Unfurnished   2.0
# 4      3.0       Ready to Move        Resale      1.0                0   3.0
#
#   type_of_building   Price_sqft
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7738 entries, 0 to 7737
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7738 non-null   int64
#  1   price             7738 non-null   float64
#  2   area              7738 non-null   float64
#  3   latitude          7738 non-null   float64
#  4   longitude         7738 non-null   float64
#  5   Bedrooms          7738 non-null   float64
#  6   Bathrooms         7738 non-null   float64
#  7   Balcony           7738 non-null   float64
#  8   Status            7738 non-null   object
#  9   neworold          7738 non-null   object
#  10  parking           7738 non-null   float64
#  11  Furnished_status  7738 non-null   object
#  12  Lift              7738 non-null   float64
#  13  type_of_building  7738 non-null   object
#  14  Price_sqft        7738 non-null   float64
# dtypes: float64(10), int64(1), object(4)
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0         price         area     latitude    longitude  \
# count  7738.000000  7.738000e+03  7738.000000  7738.000000  7738.000000
# mean   3868.500000  8.320635e+06  1409.506591    28.552092    77.273476
# std    2233.912524  7.223197e+06   718.929581     0.107420     0.180606
# min       0.000000  1.700000e+06   501.000000    28.240023    76.884101
# 25%    1934.250000  4.200000e+06   990.000000    28.455539    77.078590
# 50%    3868.500000  6.000000e+06  1250.000000    28.574637    77.345320
# 75%    5802.750000  9.500000e+06  1650.000000    28.642520    77.421054
# max    7737.000000  8.500000e+07  9500.000000    28.799748    77.688028
#
#           Bedrooms    Bathrooms      Balcony      parking         Lift  \
# count  7738.000000  7738.000000  7738.000000  7738.000000  7738.000000
# mean      2.708193     2.501163     1.619928     2.590075     0.409667
# std       0.877026     0.867050     1.445901    35.284881     0.948687
# ...

# %%
data["Status"]=data["Status"].replace("Under Construction",1)
data["Status"]=data["Status"].replace("Ready to Move",2)
# Out:
# /var/folders/9c/wr6q52nd0mn4v833r_rs5jd00000gn/T/ipykernel_28257/604643041.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data["Status"]=data["Status"].replace("Ready to Move",2)

# %%
data["neworold"]=data["neworold"].replace("New Property",1)
data["neworold"]=data["neworold"].replace("Resale",2)
# Out:
# /var/folders/9c/wr6q52nd0mn4v833r_rs5jd00000gn/T/ipykernel_28257/2479078841.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data["neworold"]=data["neworold"].replace("Resale",2)

# %%
data["Furnished_status"]=data["Furnished_status"].replace("Semi-Furnished",1)
data["Furnished_status"]=data["Furnished_status"].replace("Unfurnished",2)
data["Furnished_status"]=data["Furnished_status"].replace("Furnished",3)
# Out:
# /var/folders/9c/wr6q52nd0mn4v833r_rs5jd00000gn/T/ipykernel_28257/2304422327.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data["Furnished_status"]=data["Furnished_status"].replace("Furnished",3)

# %%
data["type_of_building"]=data["type_of_building"].replace("Flat",1)
data["type_of_building"]=data["type_of_building"].replace("Individual House",2)
# Out:
# /var/folders/9c/wr6q52nd0mn4v833r_rs5jd00000gn/T/ipykernel_28257/1946487349.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data["type_of_building"]=data["type_of_building"].replace("Individual House",2)

# %%
data.head()
# Out:
#    Unnamed: 0       price    area   latitude  longitude  Bedrooms  Bathrooms  \
# 0           0   5600000.0  1350.0  28.608850  77.460560       3.0        3.0
# 1           1   8800000.0  1490.0  28.374236  76.952416       3.0        3.0
# 2           2  16500000.0  2385.0  28.645769  77.385110       4.0        5.0
# 3           3   3810000.0  1050.0  28.566914  77.436434       2.0        2.0
# 4           4   6200000.0  1350.0  28.520732  77.356491       2.0        2.0
#
#    Balcony  Status  neworold  parking  Furnished_status  Lift  \
# 0      0.0       1         1      0.0                 0   2.0
# 1      0.0       2         1      0.0                 1   2.0
# 2      0.0       2         1      1.0                 2   0.0
# 3      3.0       0         1      1.0                 2   2.0
# 4      3.0       2         2      1.0                 0   3.0
#
#    type_of_building   Price_sqft
# 0                 1  4148.148148
# 1                 1  5906.040268
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7738 entries, 0 to 7737
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7738 non-null   int64
#  1   price             7738 non-null   float64
#  2   area              7738 non-null   float64
#  3   latitude          7738 non-null   float64
#  4   longitude         7738 non-null   float64
#  5   Bedrooms          7738 non-null   float64
#  6   Bathrooms         7738 non-null   float64
#  7   Balcony           7738 non-null   float64
#  8   Status            7738 non-null   int64
#  9   neworold          7738 non-null   int64
#  10  parking           7738 non-null   float64
#  11  Furnished_status  7738 non-null   int64
#  12  Lift              7738 non-null   float64
#  13  type_of_building  7738 non-null   int64
#  14  Price_sqft        7738 non-null   float64
# dtypes: float64(10), int64(5)
# memory usage: 906.9 KB

# %%
attribute=["price","area","Bedrooms","Bathrooms","Balcony","Lift"]
pandas.plotting.scatter_matrix(data[attribute],figsize=(12,8))
# Out:
# array([[<Axes: xlabel='price', ylabel='price'>,
#         <Axes: xlabel='area', ylabel='price'>,
#         <Axes: xlabel='Bedrooms', ylabel='price'>,
#         <Axes: xlabel='Bathrooms', ylabel='price'>,
#         <Axes: xlabel='Balcony', ylabel='price'>,
#         <Axes: xlabel='Lift', ylabel='price'>],
#        [<Axes: xlabel='price', ylabel='area'>,
#         <Axes: xlabel='area', ylabel='area'>,
#         <Axes: xlabel='Bedrooms', ylabel='area'>,
#         <Axes: xlabel='Bathrooms', ylabel='area'>,
#         <Axes: xlabel='Balcony', ylabel='area'>,
#         <Axes: xlabel='Lift', ylabel='area'>],
#        [<Axes: xlabel='price', ylabel='Bedrooms'>,
#         <Axes: xlabel='area', ylabel='Bedrooms'>,
#         <Axes: xlabel='Bedrooms', ylabel='Bedrooms'>,
#         <Axes: xlabel='Bathrooms', ylabel='Bedrooms'>,
#         <Axes: xlabel='Balcony', ylabel='Bedrooms'>,
#         <Axes: xlabel='Lift', ylabel='Bedrooms'>],
#        [<Axes: xlabel='price', ylabel='Bathrooms'>,
# ...

# %%
for i in data.columns[data.dtypes==object]:
    print("\n",i,"\n")
    print(data[i].unique())
    print(data[i].value_counts())

# %%
def editing(data):
    l=[]
    #data["District"]=[((i.split(","))[-2].lower()).strip() for i in data.Address]
    data=data[data.Price_sqft<75000]
    data.drop(columns=["Address","Status","desc","Price_sqft"],inplace=True)
    data.neworold.replace(["Resale","New Property",'Other\n\t\t\t\t\t\t\t\t\tGet Documents Verified'],[0,1,0],inplace=True)
    data.type_of_building.replace(["Flat","Individual House"],[0,1],inplace=True)
    data.Furnished_status.replace(['Semi-Furnished', 'Unfurnished', 'Furnished'],[1,0,2],inplace=True)
    for i in data.Landmarks:
        if type(i)==str:
            l.append(1)
        else:
            l.append(0)     
    data.Landmarks=l
    data.replace(np.nan,0,inplace=True)
    l=[]
    for i in data.Lift:
        if i>0:
            l.append(1)
        else:
            l.append(0)
    data.Lift=l
    l=[]        
    for i in data.parking:
        if i>0:
            l.append(1)
        else:
            l.append(0)        
    data.parking=l
    data.price=data.price/1000000
    data=data[data.price<100]
    data=data[data.price>1]
    return data  
data=editing(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/arnav/Documents/estate prj/estate.ipynb Cell 19 line 3
#      <a href='vscode-notebook-cell:/Users/arnav/Documents/estate%20prj/estate.ipynb#X30sZmlsZQ%3D%3D?line=31'>32</a>     data=data[data.price>1]
#      <a href='vscode-notebook-cell:/Users/arnav/Documents/estate%20prj/estate.ipynb#X30sZmlsZQ%3D%3D?line=32'>33</a>     return data
# ---> <a href='vscode-notebook-cell:/Users/arnav/Documents/estate%20prj/estate.ipynb#X30sZmlsZQ%3D%3D?line=33'>34</a> data=editing(data)
#
# /Users/arnav/Documents/estate prj/estate.ipynb Cell 19 line 5
#       <a href='vscode-notebook-cell:/Users/arnav/Documents/estate%20prj/estate.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a> #data["District"]=[((i.split(","))[-2].lower()).strip() for i in data.Address]
# ...
